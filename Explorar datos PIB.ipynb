# %% [markdown]
# ## Exploración datos PIB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
root = 'Data PIB 1993.xlsx'

df_pib = pd.read_excel(root)
df_pib.head()
# Out:
#   Country Name Country Code                    Series Name        Series Code  \
# 0    Argentina          ARG  Crecimiento del PIB (% anual)  NY.GDP.MKTP.KD.ZG
# 1       Belice          BLZ  Crecimiento del PIB (% anual)  NY.GDP.MKTP.KD.ZG
# 2      Bolivia          BOL  Crecimiento del PIB (% anual)  NY.GDP.MKTP.KD.ZG
# 3       Brasil          BRA  Crecimiento del PIB (% anual)  NY.GDP.MKTP.KD.ZG
# 4        Chile          CHL  Crecimiento del PIB (% anual)  NY.GDP.MKTP.KD.ZG
#
#    1993 [YR1993]  1994 [YR1994]  1995 [YR1995]  1996 [YR1996]  1997 [YR1997]  \
# 0       8.206979       5.836201      -2.845210       5.526690       8.111047
# 1       6.275692       0.131231       0.656349       1.416841       3.579933
# 2       4.269294       4.667270       4.678273       4.361343       4.954209
# 3       4.665169       5.334552       4.416731       2.207536       3.394846
# 4       6.588784       5.030198       8.933296       6.802917       7.427890
#
# ...

# %%
df_pib.tail(15)
# Out:
#             Country Name Country Code                    Series Name  \
# 9            El Salvador          SLV  Crecimiento del PIB (% anual)
# 10             Guatemala          GTM  Crecimiento del PIB (% anual)
# 11                España          ESP  Crecimiento del PIB (% anual)
# 12                Guyana          GUY  Crecimiento del PIB (% anual)
# 13                 Haití          HTI  Crecimiento del PIB (% anual)
# 14              Honduras          HND  Crecimiento del PIB (% anual)
# 15                México          MEX  Crecimiento del PIB (% anual)
# 16             Nicaragua          NIC  Crecimiento del PIB (% anual)
# 17                Panamá          PAN  Crecimiento del PIB (% anual)
# 18              Paraguay          PRY  Crecimiento del PIB (% anual)
# 19                  Perú          PER  Crecimiento del PIB (% anual)
# 20  República Dominicana          DOM  Crecimiento del PIB (% anual)
# 21              Suriname          SUR  Crecimiento del PIB (% anual)
# ...

# %%
df_pib.dropna()
# Out:
#             Country Name Country Code                    Series Name  \
# 0              Argentina          ARG  Crecimiento del PIB (% anual)
# 1                 Belice          BLZ  Crecimiento del PIB (% anual)
# 2                Bolivia          BOL  Crecimiento del PIB (% anual)
# 3                 Brasil          BRA  Crecimiento del PIB (% anual)
# 4                  Chile          CHL  Crecimiento del PIB (% anual)
# 5               Colombia          COL  Crecimiento del PIB (% anual)
# 6             Costa Rica          CRI  Crecimiento del PIB (% anual)
# 7                   Cuba          CUB  Crecimiento del PIB (% anual)
# 8                Ecuador          ECU  Crecimiento del PIB (% anual)
# 9            El Salvador          SLV  Crecimiento del PIB (% anual)
# 10             Guatemala          GTM  Crecimiento del PIB (% anual)
# 11                España          ESP  Crecimiento del PIB (% anual)
# 12                Guyana          GUY  Crecimiento del PIB (% anual)
# ...

# %%
df_pib.tail(15)
# Out:
#                                          Country Name Country Code  \
# 14                                           Honduras          HND
# 15                                             México          MEX
# 16                                          Nicaragua          NIC
# 17                                             Panamá          PAN
# 18                                           Paraguay          PRY
# 19                                               Perú          PER
# 20                               República Dominicana          DOM
# 21                                           Suriname          SUR
# 22                                            Uruguay          URY
# 23                                          Venezuela          VEN
# 24                                                NaN          NaN
# 25                                                NaN          NaN
# 26                                                NaN          NaN
# ...

# %%
df_pib.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]',
#        '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]',
#        '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]',
#        '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]',
#        '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
df_pib = df_pib.drop(['Series Name','Series Code'], axis=1)
df_pib.head()
# Out:
#   Country Name Country Code  1993 [YR1993]  1994 [YR1994]  1995 [YR1995]  \
# 0    Argentina          ARG       8.206979       5.836201      -2.845210
# 1       Belice          BLZ       6.275692       0.131231       0.656349
# 2      Bolivia          BOL       4.269294       4.667270       4.678273
# 3       Brasil          BRA       4.665169       5.334552       4.416731
# 4        Chile          CHL       6.588784       5.030198       8.933296
#
#    1996 [YR1996]  1997 [YR1997]  1998 [YR1998]  1999 [YR1999]  2000 [YR2000]  \
# 0       5.526690       8.111047       3.850179      -3.385457      -0.788999
# 1       1.416841       3.579933       3.724423       8.784632      13.019560
# 2       4.361343       4.954209       5.029352       0.426890       2.507808
# 3       2.207536       3.394846       0.338098       0.467938       4.387949
# 4       6.802917       7.427890       4.324579      -0.412096       5.326938
#
# ...

# %%
df_pib.columns = ['Country Name', 'Country Code', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
df_pib.head()
# Out:
#   Country Name Country Code      1993      1994      1995      1996      1997  \
# 0    Argentina          ARG  8.206979  5.836201 -2.845210  5.526690  8.111047
# 1       Belice          BLZ  6.275692  0.131231  0.656349  1.416841  3.579933
# 2      Bolivia          BOL  4.269294  4.667270  4.678273  4.361343  4.954209
# 3       Brasil          BRA  4.665169  5.334552  4.416731  2.207536  3.394846
# 4        Chile          CHL  6.588784  5.030198  8.933296  6.802917  7.427890
#
#        1998      1999       2000  ...       2011      2012      2013  \
# 0  3.850179 -3.385457  -0.788999  ...   6.003952 -1.026420  2.405324
# 1  3.724423  8.784632  13.019560  ...   1.922035  2.413483  1.302125
# 2  5.029352  0.426890   2.507808  ...   5.204092  5.122276  6.796011
# 3  0.338098  0.467938   4.387949  ...   3.974425  1.921150  3.004846
# 4  4.324579 -0.412096   5.326938  ...   6.110919  5.318628  4.045004
#
#        2014     2015       2016     2017     2018     2019  2020
# ...

# %%
df_pib.dtypes
# Out:
# Country Name     object
# Country Code     object
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015             object
# 2016             object
# 2017             object
# 2018             object
# 2019             object
# 2020             object
# dtype: object

# %%
df_pib['Country Name'] = df_pib['Country Name'].str.upper()
df_pib.head()
# Out:
#   Country Name Country Code      1993      1994      1995      1996      1997  \
# 0    ARGENTINA          ARG  8.206979  5.836201 -2.845210  5.526690  8.111047
# 1       BELICE          BLZ  6.275692  0.131231  0.656349  1.416841  3.579933
# 2      BOLIVIA          BOL  4.269294  4.667270  4.678273  4.361343  4.954209
# 3       BRASIL          BRA  4.665169  5.334552  4.416731  2.207536  3.394846
# 4        CHILE          CHL  6.588784  5.030198  8.933296  6.802917  7.427890
#
#        1998      1999       2000  ...       2011      2012      2013  \
# 0  3.850179 -3.385457  -0.788999  ...   6.003952 -1.026420  2.405324
# 1  3.724423  8.784632  13.019560  ...   1.922035  2.413483  1.302125
# 2  5.029352  0.426890   2.507808  ...   5.204092  5.122276  6.796011
# 3  0.338098  0.467938   4.387949  ...   3.974425  1.921150  3.004846
# 4  4.324579 -0.412096   5.326938  ...   6.110919  5.318628  4.045004
#
#        2014     2015       2016     2017     2018     2019  2020
# ...

# %%
df_pib2 = df_pib.melt(['Country Name','Country Code'])
df_pib2.head()
# Out:
#   Country Name Country Code variable    value
# 0    ARGENTINA          ARG     1993  8.20698
# 1       BELICE          BLZ     1993  6.27569
# 2      BOLIVIA          BOL     1993  4.26929
# 3       BRASIL          BRA     1993  4.66517
# 4        CHILE          CHL     1993  6.58878

# %%
df_pib2.rename(columns={'variable':'year',
                        'value': 'PIB'}, inplace=True)


df_pib2.head()
# Out:
#   Country Name Country Code  year      PIB
# 0    ARGENTINA          ARG  1993  8.20698
# 1       BELICE          BLZ  1993  6.27569
# 2      BOLIVIA          BOL  1993  4.26929
# 3       BRASIL          BRA  1993  4.66517
# 4        CHILE          CHL  1993  6.58878

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-000c9c2c4eb0> in <module>
# ----> 1 df_pib2.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

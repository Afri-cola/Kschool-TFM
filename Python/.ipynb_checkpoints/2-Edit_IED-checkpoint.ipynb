# %% [markdown]
# ## Inversión Extranjera Directa (IED)
#
# Inversión Extranjera Directa en millones de Euros
#
# - DataFrame --> df_IED

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np

# Gráficos
# ==============================================================================
import seaborn as sns
import matplotlib.pyplot as plt

# Script
# ==============================================================================
from funciones_variables import variable_porcentaje, tipo_cambio

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
root = '/home/dsc/git/Kschool-TFM/Variables_economicas/IED.csv'
df_IED = tipo_cambio(root)
df_IED= df_IED.rename(columns= {'Inversión extranjera directa, entrada neta de capital (balanza de pagos, US$ a precios actuales)': 'IED(millones€)'})

# %%
df_IED.describe()
# Out:
# variables  IED(millones€)
# count           28.000000
# mean         20117.451429
# std           9155.062614
# min           3903.580000
# 25%          13776.867500
# 50%          20402.205000
# 75%          24394.850000
# max          36945.700000

# %%
df_IED.head()
# Out:
# variables  IED(millones€)
# 1993              3903.58
# 1994              8807.63
# 1995              7113.28
# 1996              7275.91
# 1997             11720.02

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df_IED["IED(millones€)"])

# %%
sns.displot(df_IED, 
            bins=10, 
            line_kws= {'linewidth': 2},
            alpha   = 0.3, 
            kde     = True);

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=df_IED, markers = True)
plt.title('Evolución de la Inversión Extranjera Directa en México', fontsize=20, fontweight = "bold");

# %%
df_IED.sum()
# Out:
# variables
# IED(millones€)    563288.64
# dtype: float64

# %%
df_IED.loc[df_IED['IED(millones€)'] == df_IED['IED(millones€)'].max()]
# Out:
# variables  IED(millones€)
# 2013              36945.7

# %%
# %store df_IED
# Out:
# Stored 'df_IED' (DataFrame)

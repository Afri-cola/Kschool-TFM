# %% [markdown]
# # **Exploración de los datos**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def clean_data_country(root):
    "Nos devuelve el fichero de cada país limpio"
    
    df_country = pd.read_excel(root, header=1)
    df_country = df_country.drop([0], axis=0)
    df_country.rename(columns={'Unnamed: 1':'industry',
                        'Elemento': 'country'}, inplace=True)
    country_name = df_country['country'][1]
    df_country['country'] = df_country['country'].replace(np.nan, country_name)
   
  
    return df_country

# %% [markdown]
# ### Invesion española en LATAM

# %%
spanish_investment = pd.DataFrame()

# %%
directory_spain = 'Inversion España en LATAM/'

directory_spanish = pathlib.Path(directory_spain)

for file in directory_spanish.iterdir():
    country = clean_data_country(file)
    spanish_investment = pd.concat([spanish_investment, country])
# Out:
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# ...

# %%
spanish_investment.head()
# Out:
#                 country                                           industry  \
# 1  REPUBLICA DOMINICANA  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...
# 2  REPUBLICA DOMINICANA             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL
# 3  REPUBLICA DOMINICANA                             03 PESCA Y ACUICULTURA
# 4  REPUBLICA DOMINICANA        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO
# 5  REPUBLICA DOMINICANA   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL
#
#   1993 1994 1995 1996 1997 1998 1999 2000 ...  2011 2012 2013 2014 2015 2016  \
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN
#
#   2017 2018 2019 2020
# 1  NaN  NaN  NaN  NaN
# ...

# %%
spanish_investment.tail()
# Out:
#    country                                           industry 1993 1994 1995  \
# 84  PANAMA      95 REPARACIÓN ORDENADORES, EFECTOS PERSONALES  NaN  NaN  NaN
# 85  PANAMA                      96 OTROS SERVICIOS PERSONALES  NaN  NaN  NaN
# 86  PANAMA     97 ACTIVIDADES DE LOS HOGARES COMO EMPLEADORES  NaN  NaN  NaN
# 87  PANAMA       98 ACTIV. HOGARES COMO PRODUC. BIENES Y SERV  NaN  NaN  NaN
# 88  PANAMA  99 ACTIV. ORGANIZACIONES Y ORGANISMOS EXTRATER...  NaN  NaN  NaN
#
#    1996 1997 1998  1999 2000 ...  2011 2012 2013 2014 2015 2016 2017  2018  \
# 84  NaN  NaN  NaN   NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 85  NaN  NaN  NaN  6.01  NaN ...   NaN  NaN  NaN    0  NaN  NaN  NaN  4100
# 86  NaN  NaN  NaN     3  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 87  NaN  NaN  NaN   NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 88  NaN  NaN  NaN   NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
#    2019 2020
# 84  NaN  NaN
# 85  NaN  NaN
# ...

# %%
spanish_investment.dtypes
# Out:
# country     object
# industry    object
# 1993        object
# 1994        object
# 1995        object
# 1996        object
# 1997        object
# 1998        object
# 1999        object
# 2000        object
# 2001        object
# 2002        object
# 2003        object
# 2004        object
# 2005        object
# 2006        object
# 2007        object
# 2008        object
# 2009        object
# 2010        object
# 2011        object
# 2012        object
# 2013        object
# 2014        object
# 2015        object
# 2016        object
# 2017        object
# 2018        object
# 2019        object
# 2020        object
# dtype: object

# %%
print('Tamaño del DF:', spanish_investment.shape)
print('Número de valores nulos en cada columna:',spanish_investment.isnull().sum())
# Out:
# Tamaño del DF: (2113, 30)
# Número de valores nulos en cada columna: country        0
# industry       0
# 1993        1923
# 1994        1924
# 1995        1885
# 1996        1879
# 1997        1848
# 1998        1844
# 1999        1790
# 2000        1801
# 2001        1779
# 2002        1763
# 2003        1769
# 2004        1805
# 2005        1805
# 2006        1843
# 2007        1783
# 2008        1788
# 2009        1788
# 2010        1780
# 2011        1781
# 2012        1776
# 2013        1781
# 2014        1766
# 2015        1752
# 2016        1728
# 2017        1712
# 2018        1727
# 2019        1827
# 2020        1901
# dtype: int64

# %%
spanish_investment_2 = spanish_investment.melt(['industry','country'])
spanish_investment_2.head()
# Out:
#                                             industry               country  \
# 0  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...  REPUBLICA DOMINICANA
# 1             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL  REPUBLICA DOMINICANA
# 2                             03 PESCA Y ACUICULTURA  REPUBLICA DOMINICANA
# 3        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO  REPUBLICA DOMINICANA
# 4   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL  REPUBLICA DOMINICANA
#
#   variable value
# 0     1993   NaN
# 1     1993   NaN
# 2     1993   NaN
# 3     1993   NaN
# 4     1993   NaN

# %%
spanish_investment_2 = spanish_investment_2.dropna()

# %%
print('Tamaño del DF:', spanish_investment_2.shape)
print('Número de valores nulos en cada columna:',spanish_investment_2.isnull().sum())
# Out:
# Tamaño del DF: (8616, 4)
# Número de valores nulos en cada columna: industry    0
# country     0
# variable    0
# value       0
# dtype: int64

# %%
spanish_investment_2.head()
# Out:
#                                              industry               country  \
# 37                       41 CONSTRUCCIÓN DE EDIFICIOS  REPUBLICA DOMINICANA
# 40  45 VENTA Y REPARACIÓN DE VEHÍCULOS DE MOTOR Y ...  REPUBLICA DOMINICANA
# 41  46 COMER.MAYOR E INTERME.COMERCIO,EXCEP.VEHÍCU...  REPUBLICA DOMINICANA
# 48                        55 SERVICIOS DE ALOJAMIENTO  REPUBLICA DOMINICANA
# 49                  56 SERVICIOS DE COMIDAS Y BEBIDAS  REPUBLICA DOMINICANA
#
#    variable  value
# 37     1993  35.95
# 40     1993  177.9
# 41     1993    0.9
# 48     1993    1.5
# 49     1993   4.81

# %%
spanish_investment_2 = spanish_investment_2[['variable','value','country', 'industry']]
spanish_investment_2.head()
# Out:
#    variable  value               country  \
# 37     1993  35.95  REPUBLICA DOMINICANA
# 40     1993  177.9  REPUBLICA DOMINICANA
# 41     1993    0.9  REPUBLICA DOMINICANA
# 48     1993    1.5  REPUBLICA DOMINICANA
# 49     1993   4.81  REPUBLICA DOMINICANA
#
#                                              industry
# 37                       41 CONSTRUCCIÓN DE EDIFICIOS
# 40  45 VENTA Y REPARACIÓN DE VEHÍCULOS DE MOTOR Y ...
# 41  46 COMER.MAYOR E INTERME.COMERCIO,EXCEP.VEHÍCU...
# 48                        55 SERVICIOS DE ALOJAMIENTO
# 49                  56 SERVICIOS DE COMIDAS Y BEBIDAS

# %%
spanish_investment_2.rename(columns={'variable':'year',
                        'value': 'investment'}, inplace=True)
spanish_investment_2.head()
# Out:
#     year investment               country  \
# 37  1993      35.95  REPUBLICA DOMINICANA
# 40  1993      177.9  REPUBLICA DOMINICANA
# 41  1993        0.9  REPUBLICA DOMINICANA
# 48  1993        1.5  REPUBLICA DOMINICANA
# 49  1993       4.81  REPUBLICA DOMINICANA
#
#                                              industry
# 37                       41 CONSTRUCCIÓN DE EDIFICIOS
# 40  45 VENTA Y REPARACIÓN DE VEHÍCULOS DE MOTOR Y ...
# 41  46 COMER.MAYOR E INTERME.COMERCIO,EXCEP.VEHÍCU...
# 48                        55 SERVICIOS DE ALOJAMIENTO
# 49                  56 SERVICIOS DE COMIDAS Y BEBIDAS

# %%
spanish_investment_2.tail()
# Out:
#        year investment country  \
# 59137  2020       4.47  PANAMA
# 59138  2020      737.1  PANAMA
# 59147  2020          5  PANAMA
# 59148  2020     177.83  PANAMA
# 59151  2020     172.49  PANAMA
#
#                                                 industry
# 59137  70 ACTV. SEDES CENTRALES; ACTIV. CONSULTORÍA D...
# 59138    71 SERVICIOS TECNICOS ARQUITECTURA E INGENIERIA
# 59147  81 SERVICIOS A EDIFICIOS Y ACTIVIDADES DE JARD...
# 59148          82 ACTIVIDADES ADMINISTRATIVAS DE OFICINA
# 59151                          86 ACTIVIDADES SANITARIAS

# %%
spanish_investment_2.dtypes
# Out:
# year          object
# investment    object
# country       object
# industry      object
# dtype: object

# %%
#spanish_investment_2.astype({'year':'datetime64[ns]'})
# Out:
#             year investment               country  \
# 0     1993-01-01        NaN  REPUBLICA DOMINICANA
# 1     1993-01-01        NaN  REPUBLICA DOMINICANA
# 2     1993-01-01        NaN  REPUBLICA DOMINICANA
# 3     1993-01-01        NaN  REPUBLICA DOMINICANA
# 4     1993-01-01        NaN  REPUBLICA DOMINICANA
# 5     1993-01-01        NaN  REPUBLICA DOMINICANA
# 6     1993-01-01        NaN  REPUBLICA DOMINICANA
# 7     1993-01-01        NaN  REPUBLICA DOMINICANA
# 8     1993-01-01        NaN  REPUBLICA DOMINICANA
# 9     1993-01-01        NaN  REPUBLICA DOMINICANA
# 10    1993-01-01        NaN  REPUBLICA DOMINICANA
# 11    1993-01-01        NaN  REPUBLICA DOMINICANA
# 12    1993-01-01        NaN  REPUBLICA DOMINICANA
# 13    1993-01-01        NaN  REPUBLICA DOMINICANA
# 14    1993-01-01        NaN  REPUBLICA DOMINICANA
# 15    1993-01-01        NaN  REPUBLICA DOMINICANA
# 16    1993-01-01        NaN  REPUBLICA DOMINICANA
# 17    1993-01-01        NaN  REPUBLICA DOMINICANA
# ...

# %%
spanish_investment_2.head()
# Out:
#     year investment               country  \
# 37  1993      35.95  REPUBLICA DOMINICANA
# 40  1993      177.9  REPUBLICA DOMINICANA
# 41  1993        0.9  REPUBLICA DOMINICANA
# 48  1993        1.5  REPUBLICA DOMINICANA
# 49  1993       4.81  REPUBLICA DOMINICANA
#
#                                              industry
# 37                       41 CONSTRUCCIÓN DE EDIFICIOS
# 40  45 VENTA Y REPARACIÓN DE VEHÍCULOS DE MOTOR Y ...
# 41  46 COMER.MAYOR E INTERME.COMERCIO,EXCEP.VEHÍCU...
# 48                        55 SERVICIOS DE ALOJAMIENTO
# 49                  56 SERVICIOS DE COMIDAS Y BEBIDAS

# %%
df_arg_industry = spanish_investment_2[spanish_investment_2.country == 'ARGENTINA']
df_arg_industry.head()
# Out:
#       year investment    country  \
# 1144  1993      16.84  ARGENTINA
# 1146  1993     264.82  ARGENTINA
# 1162  1993    1828.28  ARGENTINA
# 1163  1993     192.21  ARGENTINA
# 1165  1993       4.51  ARGENTINA
#
#                                                industry
# 1144  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...
# 1146                             03 PESCA Y ACUICULTURA
# 1162                               20 INDUSTRIA QUÍMICA
# 1163          21 FABRICACIÓN DE PRODUCTOS FARMACÉUTICOS
# 1165  23 FABRICACIÓN DE OTROS PRODUCTOS MINERALES NO...

# %%
df_arg_industry.max()
# Out:
# year                                                2020
# investment                                   1.49127e+07
# country                                        ARGENTINA
# industry      PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# dtype: object

# %%
df_arg_industry[df_arg_industry.industry=='PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)']
# Out:
#        year investment    country                                    industry
# 1232   1993     189.03  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 3345   1994    3165.13  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 5458   1995     196.84  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 7571   1996     506.17  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 9684   1997     606.88  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 11797  1998     181.88  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 13910  1999     807.93  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 16023  2000    2347.56  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 18136  2001     491.22  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 20249  2002     586.71  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# 22362  2003     395.12  ARGENTINA  PERSONAS FÍSICAS (SIN SECTOR DE ACTIVIDAD)
# ...

# %%
df_arg_industry.to_csv('df_ARG_industry.csv',index= False, header=True)

# %%
plt.figure(figsize=(100,35))
sns.barplot(data=df_arg_industry, x='year', y='investment', hue='industry')
plt.title('Evolucion de la inversión total por paises')
# Out:
# Text(0.5, 1.0, 'Evolucion de la inversión total por paises')

# %%
sp_investment_year_country = spanish_investment_2.groupby(('year', 'country')).investment.sum().reset_index()
sp_investment_year_country.head()
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   """Entry point for launching an IPython kernel.
#    year    country  investment
# 0  1993  ARGENTINA   122415.35
# 1  1993     BELICE      584.78
# 2  1993    BOLIVIA      329.41
# 3  1993     BRASIL     6342.46
# 4  1993      CHILE     1242.12

# %%
sp_investment_year_country.tail()
# Out:
#      year                 country  investment
# 667  2020    REPUBLICA DOMINICANA      770.71
# 668  2020  SAN CRISTOBAL Y NIEVES        0.00
# 669  2020                 SURINAM        0.00
# 670  2020                 URUGUAY    11309.01
# 671  2020               VENEZUELA     3095.53

# %%
sp_investment_country = spanish_investment_2.groupby('country').investment.sum().sort_values(ascending=False).reset_index()
sp_investment_country
# Out:
#                    country   investment
# 0                ARGENTINA  40052812.14
# 1                   MEXICO   8025729.55
# 2                  URUGUAY   3464332.67
# 3                   BRASIL   2453543.53
# 4                   PANAMA   1876139.08
# 5                VENEZUELA   1655153.96
# 6               COSTA RICA    545325.78
# 7                    CHILE    453459.54
# 8                   BELICE    310416.43
# 9                  ECUADOR    274277.77
# 10                COLOMBIA    182104.48
# 11                    PERU    168878.73
# 12    REPUBLICA DOMINICANA     80379.09
# 13  SAN CRISTOBAL Y NIEVES     57732.24
# 14                    CUBA     46885.30
# 15               NICARAGUA     43314.79
# 16               GUATEMALA     25035.43
# 17                HONDURAS     18404.15
# 18                PARAGUAY     16279.01
# 19             EL SALVADOR     10938.62
# 20                 BOLIVIA      1660.32
# 21                   HAITI        17.65
# ...

# %%
plt.figure(figsize=(40,15))
sns.barplot(data=sp_investment_country, x='country', y='investment')
plt.title('Inversión total por paises')
# Out:
# Text(0.5, 1.0, 'Inversión total por paises')

# %%
plt.figure(figsize=(70,15))
sns.lineplot(data=sp_investment_year_country, x='year', y='investment', hue='country')
plt.title('Inversión total por paises')
# Out:
# Text(0.5, 1.0, 'Inversión total por paises')

# %%
plt.figure(figsize=(100,35))
sns.barplot(data=sp_investment_year_country, x='year', y='investment', hue='country')
plt.title('Evolucion de la inversión total por paises')
# Out:
# Text(0.5, 1.0, 'Evolucion de la inversión total por paises')

# %%
latam_countries = sp_investment_year_country['country'].unique()
latam_countries
# Out:
# array(['ARGENTINA', 'BELICE', 'BOLIVIA', 'BRASIL', 'CHILE', 'COLOMBIA',
#        'COSTA RICA', 'CUBA', 'ECUADOR', 'EL SALVADOR', 'GUATEMALA',
#        'GUAYANA', 'HAITI', 'HONDURAS', 'MEXICO', 'NICARAGUA', 'PANAMA',
#        'PARAGUAY', 'PERU', 'REPUBLICA DOMINICANA',
#        'SAN CRISTOBAL Y NIEVES', 'SURINAM', 'URUGUAY', 'VENEZUELA'],
#       dtype=object)

# %%
sp_investment_year_country.head()
# Out:
#    year    country  investment
# 0  1993  ARGENTINA   122415.35
# 1  1993     BELICE      584.78
# 2  1993    BOLIVIA      329.41
# 3  1993     BRASIL     6342.46
# 4  1993      CHILE     1242.12

# %%
df_ARG = sp_investment_year_country[sp_investment_year_country.country == 'ARGENTINA']
df_ARG.head()
# Out:
#     year    country  investment
# 0   1993  ARGENTINA   122415.35
# 24  1994  ARGENTINA   581152.83
# 48  1995  ARGENTINA   229211.55
# 72  1996  ARGENTINA  1179473.44
# 96  1997  ARGENTINA  2547275.12

# %%
df_ARG = df_ARG.drop(['country'], axis = 1)
df_ARG.head()
# Out:
#     year  investment
# 0   1993   122415.35
# 24  1994   581152.83
# 48  1995   229211.55
# 72  1996  1179473.44
# 96  1997  2547275.12

# %% [markdown]
# ## Modelado Series temporales

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df_ARG.dtypes
df_ARG.to_csv('df_ARG.csv',index= False, header=True)

# %%
df_ARG['year'] = df_ARG['year'].astype(int)
df_ARG.dtypes
# Out:
# year            int64
# investment    float64
# dtype: object

# %%
#df_ARG.index = df_ARG.year
df_ARG.head()
# Out:
#     year  investment
# 0   1993   122415.35
# 24  1994   581152.83
# 48  1995   229211.55
# 72  1996  1179473.44
# 96  1997  2547275.12

# %%
plt.figure(figsize=(30,5))
sns.lineplot(data=df_ARG, x='year', y='investment')
plt.title('Inversión total ARGENTINA')
# Out:
# Text(0.5, 1.0, 'Inversión total ARGENTINA')

# %%
x = df_ARG

sarima_model = SARIMAX(x, order=(2,0,1))
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-ba9f9f20c6b4> in <module>
#       1 x = df_ARG
#       2
# ----> 3 sarima_model = SARIMAX(x, order=(2,0,1))
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py in __init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, **kwargs)
#     509         self.nobs = len(endog)
#     510         self.k_states = k_states
# --> 511         self.k_posdef = k_posdef
#     512
# ...

# %%
vresults = sarima_model.fit()

# %%
results.aic

# %% [markdown]
# ### **Inversión LATAM en España**

# %%
latam_investment = pd.DataFrame()

# %%
directory = 'Inversion LATAM en España/'

directory_latam = pathlib.Path(directory)

for file in directory_latam.iterdir():
    country = clean_data_country(file)
    latam_investment = pd.concat([latam_investment, country])
# Out:
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# ...

# %%
latam_investment.head()
# Out:
#    country                                           industry   1993 1994  \
# 1  BOLIVIA  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...  90.15  NaN
# 2  BOLIVIA             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL    NaN  NaN
# 3  BOLIVIA                             03 PESCA Y ACUICULTURA    NaN  NaN
# 4  BOLIVIA        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO    NaN  NaN
# 5  BOLIVIA   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL    NaN  NaN
#
#   1995  1996 1997 1998 1999 2000 ...  2011 2012 2013 2014 2015  2016 2017  \
# 1  NaN  0.99  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  38.5  NaN
# 2  NaN   NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN   NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN   NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 5  NaN   NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
#   2018 2019 2020
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  NaN  NaN
# ...

# %%
latam_investment.tail()
# Out:
#      country                                           industry 1993 1994  \
# 84  HONDURAS      95 REPARACIÓN ORDENADORES, EFECTOS PERSONALES  NaN  NaN
# 85  HONDURAS                      96 OTROS SERVICIOS PERSONALES  NaN  NaN
# 86  HONDURAS     97 ACTIVIDADES DE LOS HOGARES COMO EMPLEADORES  NaN  NaN
# 87  HONDURAS       98 ACTIV. HOGARES COMO PRODUC. BIENES Y SERV  NaN  NaN
# 88  HONDURAS  99 ACTIV. ORGANIZACIONES Y ORGANISMOS EXTRATER...  NaN  NaN
#
#    1995 1996 1997 1998 1999 2000 ...  2011 2012 2013 2014 2015 2016 2017 2018  \
# 84  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 85  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 86  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 87  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 88  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    2019 2020
# 84  NaN  NaN
# 85  NaN  NaN
# ...

# %%
latam_investment.dtypes
# Out:
# country     object
# industry    object
# 1993        object
# 1994        object
# 1995        object
# 1996        object
# 1997        object
# 1998        object
# 1999        object
# 2000        object
# 2001        object
# 2002        object
# 2003        object
# 2004        object
# 2005        object
# 2006        object
# 2007        object
# 2008        object
# 2009        object
# 2010        object
# 2011        object
# 2012        object
# 2013        object
# 2014        object
# 2015        object
# 2016        object
# 2017        object
# 2018        object
# 2019        object
# 2020        object
# dtype: object

# %%
print('Tamaño del DF:', latam_investment.shape)
print('Número de valores nulos en cada columna:',latam_investment.isnull().sum())
# Out:
# Tamaño del DF: (2112, 30)
# Número de valores nulos en cada columna: country        0
# industry       0
# 1993        1924
# 1994        1924
# 1995        1890
# 1996        1878
# 1997        1853
# 1998        1861
# 1999        1805
# 2000        1804
# 2001        1777
# 2002        1724
# 2003        1738
# 2004        1773
# 2005        1798
# 2006        1829
# 2007        1785
# 2008        1780
# 2009        1783
# 2010        1772
# 2011        1764
# 2012        1759
# 2013        1757
# 2014        1735
# 2015        1731
# 2016        1702
# 2017        1675
# 2018        1675
# 2019        1795
# 2020        1864
# dtype: int64

# %%
latam_investment_2 = latam_investment.melt(['industry','country'])
latam_investment_2.head()
# Out:
#                                             industry  country variable  value
# 0  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...  BOLIVIA     1993  90.15
# 1             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL  BOLIVIA     1993    NaN
# 2                             03 PESCA Y ACUICULTURA  BOLIVIA     1993    NaN
# 3        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO  BOLIVIA     1993    NaN
# 4   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL  BOLIVIA     1993    NaN

# %%
latam_investment_2 = latam_investment_2[['variable','value','country', 'industry']]
latam_investment_2.head()
# Out:
#   variable  value  country                                           industry
# 0     1993  90.15  BOLIVIA  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...
# 1     1993    NaN  BOLIVIA             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL
# 2     1993    NaN  BOLIVIA                             03 PESCA Y ACUICULTURA
# 3     1993    NaN  BOLIVIA        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO
# 4     1993    NaN  BOLIVIA   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL

# %%
latam_investment_2.rename(columns={'variable':'year',
                        'value': 'investment'}, inplace=True)
latam_investment_2.head()
# Out:
#    year investment  country                                           industry
# 0  1993      90.15  BOLIVIA  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...
# 1  1993        NaN  BOLIVIA             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL
# 2  1993        NaN  BOLIVIA                             03 PESCA Y ACUICULTURA
# 3  1993        NaN  BOLIVIA        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO
# 4  1993        NaN  BOLIVIA   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL

# %%
lat_investment_year_country = latam_investment_2.groupby(('year', 'country')).investment.sum().reset_index()
lat_investment_year_country.head()
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   """Entry point for launching an IPython kernel.
#    year    country  investment
# 0  1993  ARGENTINA      838.54
# 1  1993     BELICE      584.78
# 2  1993    BOLIVIA      329.41
# 3  1993     BRASIL     6342.46
# 4  1993      CHILE     1242.12

# %%
lat_investment_country = latam_investment_2.groupby('country').investment.sum().sort_values(ascending=False).reset_index()
lat_investment_country
# Out:
#                    country   investment
# 0                  URUGUAY  13330019.60
# 1                   MEXICO  12477320.14
# 2                   BRASIL   7390808.49
# 3                    CHILE   4973791.34
# 4               COSTA RICA   4511278.89
# 5                 COLOMBIA   3439736.58
# 6                   PANAMA   2878706.39
# 7                VENEZUELA   1896664.21
# 8                ARGENTINA   1525005.70
# 9                     PERU    563096.12
# 10                 ECUADOR    333838.40
# 11                  BELICE    326744.09
# 12                 BOLIVIA    114876.18
# 13    REPUBLICA DOMINICANA     81509.27
# 14  SAN CRISTOBAL Y NIEVES     57732.24
# 15               NICARAGUA     56836.63
# 16                    CUBA     48016.29
# 17               GUATEMALA     26522.83
# 18             EL SALVADOR     18461.12
# 19                HONDURAS     18404.15
# 20                PARAGUAY     16279.01
# 21                   HAITI        17.65
# ...

# %%
plt.figure(figsize=(40,15))
sns.barplot(data=lat_investment_country, x='country', y='investment')
plt.title('Inversión total por paises. LATAM en España')
# Out:
# Text(0.5, 1.0, 'Inversión total por paises. LATAM en España')

# %%
plt.figure(figsize=(70,15))
sns.lineplot(data=lat_investment_year_country, x='year', y='investment', hue='country')
plt.title('Inversión total por paises. LATAM en España')
# Out:
# Text(0.5, 1.0, 'Inversión total por paises. LATAM en España')

# %% [markdown]
# ## Modelo de Machine Learning

# %%
sp_investment_year_country.head()
# Out:
#    year    country  investment
# 0  1993  ARGENTINA   122415.35
# 1  1993     BELICE      584.78
# 2  1993    BOLIVIA      329.41
# 3  1993     BRASIL     6342.46
# 4  1993      CHILE     1242.12

# %%
sp_argentina_year = sp_investment_year_country[sp_investment_year_country.country== 'ARGENTINA']
sp_argentina_year.head()
# Out:
#     year    country  investment
# 0   1993  ARGENTINA   122415.35
# 24  1994  ARGENTINA   581152.83
# 48  1995  ARGENTINA   229211.55
# 72  1996  ARGENTINA  1179473.44
# 96  1997  ARGENTINA  2547275.12

# %%
target = sp_argentina_year['investment']
features = sp_argentina_year[['year']]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, roc_curve, f1_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
lr = LogisticRegression()

X_train, X_test, y_train, y_test = train_test_split(features, target)

lr.fit(X_train, y_train)
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-cf83fb3a1c84> in <module>
#       3 X_train, X_test, y_train, y_test = train_test_split(features, target)
#       4
# ----> 5 lr.fit(X_train, y_train)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1284         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1285                          accept_large_sparse=solver != 'liblinear')
# -> 1286         check_classification_targets(y)
#    1287         self.classes_ = np.unique(y)
#    1288         n_samples, n_features = X.shape
#
# ...

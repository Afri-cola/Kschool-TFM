# %% [markdown]
# ## **Exploración de los datos**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
root_arg = 'Inversion España en LATAM/España en Argentina_2.xls'
root_belice = 'Inversion España en LATAM/España en Belice_2.xls'
root_bolivia = 'Inversion España en LATAM/España en Bolivia_2.xls'
root_brasil = 'Inversion España en LATAM/España en Brasil_2.xls'
root_chile = 'Inversion España en LATAM/España en Chile_2.xls'
root_colombia = 'Inversion España en LATAM/España en Colombia_2.xls'
root_costarica = 'Inversion España en LATAM/España en Costa Rica_2.xls'
root_cuba = 'Inversion España en LATAM/España en Cuba_2.xls'
root_ecuador = 'Inversion España en LATAM/España en Ecuador_2.xls'
root_elsalvador = 'Inversion España en LATAM/España en El Salvador_2.xls'
root_guatemala = 'Inversion España en LATAM/España en Guatemala_2.xls'
root_guayana = 'Inversion España en LATAM/España en Guayana_2.xls'
root_haiti = 'Inversion España en LATAM/España en Haiti_2.xls'
root_mexico = 'Inversion España en LATAM/España en México_2.xls'
root_nicaragua = 'Inversion España en LATAM/España en Nicaragua_2.xls'
root_panama = 'Inversion España en LATAM/España en Panama_2.xls'
root_paraguay = 'Inversion España en LATAM/España en Paraguay_2.xls'
root_peru = 'Inversion España en LATAM/España en Peru_2.xls'
root_repdomin = 'Inversion España en LATAM/España en Republica Dominicana_2.xls'
root_sancristobal = 'Inversion España en LATAM/España en San Critobal y Nieves_2.xls'
root_surinam = 'Inversion España en LATAM/España en Surinam_2.xls'
root_uruguay = 'Inversion España en LATAM/España en Uruguay_2.xls'

# %%
def clean_data_country(root):
    "Nos devuelve el fichero de cada país limpio"
    
    df_country = pd.read_excel(root, header=1)
    df_country = df_country.drop([0], axis=0)
    df_country.rename(columns={'Unnamed: 1':'industry',
                        'Elemento': 'country'}, inplace=True)
    country_name = df_country['country'][1]
    df_country['country'] = df_country['country'].replace(np.nan, country_name)
   
  
    return df_country

# %%
latam_investment = pd.DataFrame()

# %%
df_arg = clean_data_country(root_arg)
# Out:
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
#       country                                           industry     1993  \
# 1   ARGENTINA  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...    16.84
# 2   ARGENTINA             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL      NaN
# 3   ARGENTINA                             03 PESCA Y ACUICULTURA   264.82
# 4   ARGENTINA        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO      NaN
# 5   ARGENTINA   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL      NaN
# 6   ARGENTINA               07 EXTRACCIÓN DE MINERALES METÁLICOS      NaN
# 7   ARGENTINA                    08 OTRAS INDUSTRIAS EXTRACTIVAS      NaN
# 8   ARGENTINA  09 ACTIVIDADES DE APOYO A LAS INDUSTRIAS EXTRA...      NaN
# 9   ARGENTINA                    10 INDUSTRIA DE LA ALIMENTACIÓN      NaN
# 10  ARGENTINA                          11 FABRICACIÓN DE BEBIDAS      NaN
# 11  ARGENTINA                            12 INDUSTRIA DEL TABACO      NaN
# ...

# %%
df_belice = pd.read_excel(root_belice, header=1)
df_belice= df_belice.drop([0], axis=0)
df_belice.rename(columns={'Unnamed: 1':'industry',
                        'Elemento': 'country'}, inplace=True)
df_belice['country'] = df_belice['country'].replace(np.nan, 'BELICE')
print('tamaño del DF:', df_belice.shape)
df_belice.head()
# Out:
# WARNING *** file size (32704) not 512 + multiple of sector size (512)
# tamaño del DF: (88, 30)
#   country                                           industry   1993 1994 1995  \
# 1  BELICE  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...   3.01  NaN  NaN
# 2  BELICE             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL    NaN  NaN  NaN
# 3  BELICE                             03 PESCA Y ACUICULTURA  30.05  NaN  NaN
# 4  BELICE        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO    NaN  NaN  NaN
# 5  BELICE   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL    NaN  NaN  NaN
#
#    1996  1997  1998  1999   2000 ...  2011 2012 2013 2014 2015 2016 2017 2018  \
# 1  60.1  60.1  60.1  60.1  120.2 ...     0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   NaN   NaN   NaN   NaN    NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3   NaN   NaN   NaN   NaN    NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN   NaN   NaN   NaN    NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
df = pd.concat([df_arg, df_belice])
df.head()
# Out:
#      country                                           industry    1993  \
# 1  ARGENTINA  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...   16.84
# 2  ARGENTINA             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL     NaN
# 3  ARGENTINA                             03 PESCA Y ACUICULTURA  264.82
# 4  ARGENTINA        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO     NaN
# 5  ARGENTINA   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL     NaN
#
#      1994     1995    1996     1997     1998    1999     2000   ...    \
# 1  171.65      NaN  212.76      NaN   1878.3   32.91      NaN   ...
# 2     NaN  3736.37  1775.7  8870.99   139.92  777.61  1573.47   ...
# 3  120.55   602.08    50.2  1142.54  4756.08       0  5781.05   ...
# 4     NaN      NaN     NaN      NaN      NaN     NaN      NaN   ...
# 5     NaN      NaN     NaN      NaN      NaN     NaN      NaN   ...
#
#       2011 2012    2013    2014 2015     2016    2017   2018   2019    2020
# ...

# %%
df.tail()
# Out:
#    country                                           industry 1993 1994 1995  \
# 84  BELICE      95 REPARACIÓN ORDENADORES, EFECTOS PERSONALES  NaN  NaN  NaN
# 85  BELICE                      96 OTROS SERVICIOS PERSONALES  NaN  NaN  NaN
# 86  BELICE     97 ACTIVIDADES DE LOS HOGARES COMO EMPLEADORES  NaN  NaN  NaN
# 87  BELICE       98 ACTIV. HOGARES COMO PRODUC. BIENES Y SERV  NaN  NaN  NaN
# 88  BELICE  99 ACTIV. ORGANIZACIONES Y ORGANISMOS EXTRATER...  NaN  NaN  NaN
#
#    1996 1997  1998   1999  2000 ...  2011 2012 2013 2014 2015 2016 2017 2018  \
# 84  NaN  NaN   NaN    NaN   NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 85  NaN  NaN  2.03  31.49  3.01 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 86  NaN  NaN   NaN    NaN   NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 87  NaN  NaN   NaN    NaN   NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 88  NaN  NaN   NaN    NaN   NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    2019 2020
# 84  NaN  NaN
# ...

# %%
df.shape
# Out:
# (177, 30)

# %%
root_bolivia = 'Inversion España en LATAM/España en Bolivia_2.xls'
df_bolivia = pd.read_excel(root_bolivia, header=1)
df_bolivia = df_bolivia.drop([0], axis=0)
df_bolivia.rename(columns={'Unnamed: 1':'industry',
                        'Elemento': 'country'}, inplace=True)
df_bolivia['country'] = df_bolivia['country'].replace(np.nan, 'BOLIVIA')
print('tamaño del DF:', df_bolivia.shape)
# Out:
# WARNING *** file size (24512) not 512 + multiple of sector size (512)
# tamaño del DF: (88, 30)

# %%
df = pd.concat([df, df_bolivia])
df.head()
# Out:
#      country                                           industry    1993  \
# 1  ARGENTINA  01 AGRICULTURA, GANADERÍA, CAZA Y SERV. RELACI...   16.84
# 2  ARGENTINA             02 SILVICULTURA Y EXPLOTACIÓN FORESTAL     NaN
# 3  ARGENTINA                             03 PESCA Y ACUICULTURA  264.82
# 4  ARGENTINA        05 EXTRACCIÓN DE ANTRACITA, HULLA Y LIGNITO     NaN
# 5  ARGENTINA   06 EXTRACCIÓN DE CRUDO DE PETRÓLEO Y GAS NATURAL     NaN
#
#      1994     1995    1996     1997     1998    1999     2000   ...    \
# 1  171.65      NaN  212.76      NaN   1878.3   32.91      NaN   ...
# 2     NaN  3736.37  1775.7  8870.99   139.92  777.61  1573.47   ...
# 3  120.55   602.08    50.2  1142.54  4756.08       0  5781.05   ...
# 4     NaN      NaN     NaN      NaN      NaN     NaN      NaN   ...
# 5     NaN      NaN     NaN      NaN      NaN     NaN      NaN   ...
#
#       2011 2012    2013    2014 2015     2016    2017   2018   2019    2020
# ...

# %%
df.shape
# Out:
# (265, 30)

# %% [markdown]
# ## Deuda externa acumulada
#
# - DataFrame --> df_deuda

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
root = 'Tipo de cambio- Dolar a Euro.csv'

df = pd.read_csv(root)
df.head()
# Out:
#        Unnamed: 0    1993    1994    1995    1996    1997    1998    1999  \
# 0  Tipo de cambio  0.8894  0.8027  0.7467  0.7921  0.9135  0.8526  0.9926
#
#      2000    2001   ...      2011    2012    2013    2014    2015    2016  \
# 0  1.0611  1.1225   ...    0.7727  0.7577  0.7274  0.8264  0.9207  0.9507
#
#      2017    2018    2019    2020
# 0  0.8333  0.8717  0.8917  0.8185
#
# [1 rows x 29 columns]

# %%
df.head()
# Out:
#        Unnamed: 0    1993    1994    1995    1996    1997    1998    1999  \
# 0  Tipo de cambio  0.8894  0.8027  0.7467  0.7921  0.9135  0.8526  0.9926
#
#      2000    2001   ...      2011    2012    2013    2014    2015    2016  \
# 0  1.0611  1.1225   ...    0.7727  0.7577  0.7274  0.8264  0.9207  0.9507
#
#      2017    2018    2019    2020
# 0  0.8333  0.8717  0.8917  0.8185
#
# [1 rows x 29 columns]

# %%
df.rename(columns={'Unnamed: 0' : 'variables'}, inplace=True)

# %%
df= df.replace({'Tipo de cambio': 'Deuda Externa(millones€)'})

# %%
root_2 = 'Variables_economicas/deuda externa acumulada.csv'

df_deuda = pd.read_csv(root_2, header=0)
df_deuda.rename(columns={'Country Name':'country', 'Indicator Name':'variables' }, inplace=True)
df_deuda = df_deuda[df_deuda.country == 'México']
df_deuda = df_deuda.drop(['Indicator Code', 'Country Code'], axis=1)
df_deuda['country'] = df_deuda['country'].replace('México', 'MEXICO')
df_deuda= df_deuda.replace({'Deuda externa acumulada, total (DOD, US$ a precios actuales)': 'Deuda Externa(millones€)'})



df_deuda.head()
# Out:
#     country                 variables          1993          1994  \
# 152  MEXICO  Deuda Externa(millones€)  1.318525e+11  1.399149e+11
#
#              1995          1996          1997          1998          1999  \
# 152  1.667340e+11  1.575828e+11  1.488449e+11  1.601798e+11  1.679746e+11
#
#              2000  ...           2011          2012          2013  \
# 152  1.525580e+11  ...   2.917844e+11  3.492760e+11  4.062386e+11
#
#              2014          2015          2016          2017          2018  \
# 152  4.424259e+11  4.269139e+11  4.219042e+11  4.415767e+11  4.531578e+11
#
#              2019  2020
# 152  4.697287e+11   NaN
#
# [1 rows x 30 columns]

# %%
df_deuda = df_deuda.drop(['country'], axis=1)

# %%
df_deuda.set_index('variables', inplace=True)

# %%
df_deuda.head()
# Out:
#                                   1993          1994          1995  \
# variables
# Deuda Externa(millones€)  1.318525e+11  1.399149e+11  1.667340e+11
#
#                                   1996          1997          1998  \
# variables
# Deuda Externa(millones€)  1.575828e+11  1.488449e+11  1.601798e+11
#
#                                   1999          2000          2001  \
# variables
# Deuda Externa(millones€)  1.679746e+11  1.525580e+11  1.660645e+11
#
#                                   2002  ...           2011          2012  \
# variables                               ...
# Deuda Externa(millones€)  1.572737e+11  ...   2.917844e+11  3.492760e+11
#
#                                   2013          2014          2015  \
# variables
# Deuda Externa(millones€)  4.062386e+11  4.424259e+11  4.269139e+11
#
#                                   2016          2017          2018  \
# variables
# Deuda Externa(millones€)  4.219042e+11  4.415767e+11  4.531578e+11
#
# ...

# %%
df_deuda = df_deuda.div(1000000)
df_deuda.head()
# Out:
#                                    1993           1994           1995  \
# variables
# Deuda Externa(millones€)  131852.484881  139914.928843  166734.035992
#
#                                    1996           1997           1998  \
# variables
# Deuda Externa(millones€)  157582.830604  148844.858128  160179.820334
#
#                                    1999           2000           2001  \
# variables
# Deuda Externa(millones€)  167974.626592  152557.992415  166064.500843
#
#                                    2002  ...            2011           2012  \
# variables                                ...
# Deuda Externa(millones€)  157273.704963  ...   291784.441992  349275.996311
#
#                                   2013           2014           2015  \
# variables
# Deuda Externa(millones€)  406238.58978  442425.894709  426913.933056
#
#                                  2016           2017           2018  \
# variables
# ...

# %%
df.set_index('variables', inplace=True)
df.head()
# Out:
#                             1993    1994    1995    1996    1997    1998  \
# variables
# Deuda Externa(millones€)  0.8894  0.8027  0.7467  0.7921  0.9135  0.8526
#
#                             1999    2000    2001    2002   ...      2011  \
# variables                                                  ...
# Deuda Externa(millones€)  0.9926  1.0611  1.1225  0.9524   ...    0.7727
#
#                             2012    2013    2014    2015    2016    2017  \
# variables
# Deuda Externa(millones€)  0.7577  0.7274  0.8264  0.9207  0.9507  0.8333
#
#                             2018    2019    2020
# variables
# Deuda Externa(millones€)  0.8717  0.8917  0.8185
#
# [1 rows x 28 columns]

# %%
df_deuda = df_deuda.mul(df, axis=0)
df_deuda.head()
# Out:
#                                    1993           1994           1995  \
# variables
# Deuda Externa(millones€)  117269.600053  112309.713382  124500.304676
#
#                                    1996         1997           1998  \
# variables
# Deuda Externa(millones€)  124821.360122  135969.7779  136569.314817
#
#                                    1999           2000           2001  \
# variables
# Deuda Externa(millones€)  166731.614355  161879.285751  186407.402196
#
#                                    2002  ...            2011           2012  \
# variables                                ...
# Deuda Externa(millones€)  149787.476606  ...   225461.838327  264646.422405
#
#                                    2013           2014           2015  \
# variables
# Deuda Externa(millones€)  295497.950206  365620.759387  393059.658164
#
#                                    2016          2017           2018  \
# variables
# ...

# %%
df_deuda = df_deuda.round(2)

# %%
df_deuda = df_deuda.transpose()

# %%
df_deuda.describe()
# Out:
# variables  Deuda Externa(millones€)
# count                     27.000000
# mean                  209627.560000
# std                   107746.827303
# min                   112309.710000
# 25%                   131814.775000
# 50%                   149787.480000
# 75%                   280072.185000
# max                   418857.120000

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df_deuda["Deuda Externa(millones€)"])

# %%
sns.displot(df_deuda, bins=10)

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=df_deuda)
plt.title('Evolución de la Deuda Externa de México')
# Out:
# Text(0.5, 1.0, 'Evolución de la Deuda Externa de México')

# %%
df_deuda.sum()
# Out:
# variables
# Deuda Externa(millones€)    5659944.12
# dtype: float64

# %%
df_deuda.loc[df_deuda['Deuda Externa(millones€)']== df_deuda['Deuda Externa(millones€)'].max()]
# Out:
# variables  Deuda Externa(millones€)
# 2019                      418857.12

# %%
# %store df_deuda
# Out:
# Stored 'df_deuda' (DataFrame)
